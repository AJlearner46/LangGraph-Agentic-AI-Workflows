# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatGoogleGenerativeAI(model="gemini-2.0-flash",)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': "## Blog Outline: Rise of AI in India\n\n**I. Introduction: Setting the Stage**\n\n   *   **A. Hook:** Start with a compelling statistic or anecdote about AI's impact in India (e.g., AI-powered healthcare diagnosis in rural areas).\n   *   **B. Context:** Briefly introduce Artificial Intelligence (AI) and its growing global significance.\n   *   **C. Thesis Statement:** Assert that India is rapidly emerging as a significant player in the global AI landscape, driven by a unique combination of factors and facing both opportunities and challenges.\n   *   **D. Blog Structure (Brief Overview):** Briefly mention the main topics to be covered in the blog post (e.g., key drivers, applications, government initiatives, challenges, and future prospects).\n\n**II. Key Drivers Fueling the AI Revolution in India:**\n\n   *   **A. Demographic Advantage:**\n        *   1.  Large and young population: Highlight the potential for a skilled workforce.\n        *   2.  Growing digital literacy: Mention the increasing access to technology and internet penetration.\n   *   **B. Data Abundance:**\n        *   1.  Vast amounts of data generation: Explain the potential of this data for training AI models.\n        *   2.  Data localization policies: Discuss the impact of these policies on AI development.\n   *   **C. Government Support and Initiatives:**\n        *   1.  National AI Strategy: Detail the key objectives and goals of the strategy.\n        *   2.  AI-related policies and regulations: Discuss policies promoting AI adoption and addressing ethical concerns.\n        *   3.  Funding and R&D support: Highlight government investments in AI research and development.\n   *   **D. Thriving Startup Ecosystem:**\n        *   1.  Emergence of AI startups: Showcase examples of successful AI startups in India.\n        *   2.  Venture capital investment: Discuss the increasing flow of investment into Indian AI startups.\n        *   3.  Innovation hubs and accelerators: Mention the role of these in fostering AI innovation.\n   *   **E. Cost-Effectiveness:**\n        *   1.  Lower development costs compared to developed nations: Explain how this attracts investment and innovation.\n        *   2.  Availability of skilled but relatively affordable talent: Highlight the cost advantage in AI development.\n\n**III. AI Applications Across Key Sectors in India:**\n\n   *   **A. Healthcare:**\n        *   1.  AI-powered diagnostics: Examples of AI used for early disease detection.\n        *   2.  Personalized medicine: How AI is tailoring treatments to individual patients.\n        *   3.  Remote healthcare and telemedicine: AI's role in improving healthcare access in rural areas.\n   *   **B. Agriculture:**\n        *   1.  Precision farming: AI-driven solutions for optimizing crop yields and resource management.\n        *   2.  Crop monitoring and disease detection: Using AI to identify and address agricultural challenges.\n        *   3.  Supply chain optimization: Improving efficiency and reducing waste in the agricultural supply chain.\n   *   **C. Finance:**\n        *   1.  Fraud detection and prevention: AI algorithms identifying and preventing fraudulent transactions.\n        *   2.  Risk assessment and credit scoring: Using AI to evaluate creditworthiness.\n        *   3.  Customer service chatbots: AI-powered chatbots providing customer support.\n   *   **D. Education:**\n        *   1.  Personalized learning: AI adapting learning content to individual student needs.\n        *   2.  Automated grading and feedback: AI streamlining the grading process for educators.\n        *   3.  Accessible education for remote areas: AI facilitating online learning and bridging the education gap.\n   *   **E. Transportation:**\n        *   1.  Smart traffic management: AI optimizing traffic flow and reducing congestion.\n        *   2.  Autonomous vehicles: Research and development of self-driving vehicles.\n       ...

# %%
print(final_state['outline'])
# Out:
# ## Blog Outline: Rise of AI in India
#
# **I. Introduction: Setting the Stage**
#
#    *   **A. Hook:** Start with a compelling statistic or anecdote about AI's impact in India (e.g., AI-powered healthcare diagnosis in rural areas).
#    *   **B. Context:** Briefly introduce Artificial Intelligence (AI) and its growing global significance.
#    *   **C. Thesis Statement:** Assert that India is rapidly emerging as a significant player in the global AI landscape, driven by a unique combination of factors and facing both opportunities and challenges.
#    *   **D. Blog Structure (Brief Overview):** Briefly mention the main topics to be covered in the blog post (e.g., key drivers, applications, government initiatives, challenges, and future prospects).
#
# **II. Key Drivers Fueling the AI Revolution in India:**
#
#    *   **A. Demographic Advantage:**
#         *   1.  Large and young population: Highlight the potential for a skilled workforce.
#         *   2.  Growing digital literacy: Mention the increasing access to technology and internet penetration.
#    *   **B. Data Abundance:**
#         *   1.  Vast amounts of data generation: Explain the potential of this data for training AI models.
#         *   2.  Data localization policies: Discuss the impact of these policies on AI development.
#    *   **C. Government Support and Initiatives:**
#         *   1.  National AI Strategy: Detail the key objectives and goals of the strategy.
#         *   2.  AI-related policies and regulations: Discuss policies promoting AI adoption and addressing ethical concerns.
#         *   3.  Funding and R&D support: Highlight government investments in AI research and development.
#    *   **D. Thriving Startup Ecosystem:**
#         *   1.  Emergence of AI startups: Showcase examples of successful AI startups in India.
#         *   2.  Venture capital investment: Discuss the increasing flow of investment into Indian AI startups.
#         *   3.  Innovation hubs and accelerators: Mention the role of these in fostering AI innovation.
#    *   **E. Cost-Effectiveness:**
#         *   1.  Lower development costs compared to developed nations: Explain how this attracts investment and innovation.
#         *   2.  Availability of skilled but relatively affordable talent: Highlight the cost advantage in AI development.
#
# **III. AI Applications Across Key Sectors in India:**
#
#    *   **A. Healthcare:**
#         *   1.  AI-powered diagnostics: Examples of AI used for early disease detection.
#         *   2.  Personalized medicine: How AI is tailoring treatments to individual patients.
#         *   3.  Remote healthcare and telemedicine: AI's role in improving healthcare access in rural areas.
#    *   **B. Agriculture:**
#         *   1.  Precision farming: AI-driven solutions for optimizing crop yields and resource management.
#         *   2.  Crop monitoring and disease detection: Using AI to identify and address agricultural challenges.
#         *   3.  Supply chain optimization: Improving efficiency and reducing waste in the agricultural supply chain.
#    *   **C. Finance:**
#         *   1.  Fraud detection and prevention: AI algorithms identifying and preventing fraudulent transactions.
#         *   2.  Risk assessment and credit scoring: Using AI to evaluate creditworthiness.
#         *   3.  Customer service chatbots: AI-powered chatbots providing customer support.
#    *   **D. Education:**
#         *   1.  Personalized learning: AI adapting learning content to individual student needs.
#         *   2.  Automated grading and feedback: AI streamlining the grading process for educators.
#         *   3.  Accessible education for remote areas: AI facilitating online learning and bridging the education gap.
#    *   **E. Transportation:**
#         *   1.  Smart traffic management: AI optimizing traffic flow and reducing congestion.
#         *   2.  Autonomous vehicles: Research and development of self-driving vehicles.
#         *   3.  Improved logistics and supply chain efficiency: AI optimizing delivery routes and logistics operations.
#
# **IV. Challenges and Concerns:**
#
#    *   **A. Data Privacy and Security:**
#         *   1.  Concerns about data breaches and misuse: Addressing the need for robust data protection measures.
#         *   2.  Lack of clear data privacy regulations: Highlighting the need for comprehensive data privacy laws.
#    *   **B. Ethical Considerations:**
#         *   1.  Bias in AI algorithms: Addressing the potential for bias in AI models and ensuring fairness.
#         *   2.  Accountability and transparency: Establishing clear lines of responsibility for AI decisions.
#         *   3.  Job displacement due to automation: Discussing the potential impact of AI on employment and the need for reskilling initiatives.
#    *   **C. Infrastructure Gaps:**
#         *   1.  Limited access to high-speed internet in rural areas: Addressing the digital divide and ensuring equitable access to AI technologies.
#         *   2.  Lack of adequate computing infrastructure: Investing in the necessary computing resources to support AI development and deployment.
#    *   **D. Skill Gap:**
#         *   1.  Shortage of skilled AI professionals: Highlighting the need for AI education and training programs.
#         *   2.  Need for reskilling and upskilling the workforce: Preparing the workforce for the changing job market.
#
# **V. The Future of AI in India: Opportunities and Potential:**
#
#    *   **A. AI as a Growth Engine:**
#         *   1.  Potential for economic growth and job creation: Discussing the economic benefits of AI adoption.
#         *   2.  Improving efficiency and productivity across sectors: Highlighting the potential for AI to drive productivity gains.
#    *   **B. Global Leadership in Specific AI Domains:**
#         *   1.  Leveraging India's strengths in specific areas (e.g., healthcare AI, agricultural AI): Identifying areas where India can become a global leader.
#         *   2.  Promoting collaboration between academia, industry, and government: Fostering a collaborative ecosystem for AI innovation.
#    *   **C. Addressing Societal Challenges:**
#         *   1.  Using AI to solve pressing social problems (e.g., poverty, inequality, climate change): Exploring the potential of AI to address societal challenges.
#         *   2.  Improving the quality of life for all citizens: Highlighting the potential for AI to improve the lives of all Indians.
#
# **VI. Conclusion:**
#
#    *   **A. Recap of Key Points:** Briefly summarize the main drivers, applications, challenges, and future prospects of AI in India.
#    *   **B. Optimistic Outlook:** Emphasize the potential of AI to transform India and improve the lives of its citizens.
#    *   **C. Call to Action:** Encourage readers to learn more about AI and its applications in India, and to consider the ethical implications of AI development.
#    *   **D. Final Thought-provoking Statement:** End with a powerful statement about the future of AI in India and its potential to shape the future of the world.
#
# **VII. Optional Elements:**
#
# *   **Visuals:** Include relevant images, charts, and infographics to enhance the blog post.
# *   **Quotes:** Incorporate quotes from industry experts, government officials, and researchers.
# *   **Case Studies:** Feature real-world examples of successful AI implementations in India.
# *   **Interactive Elements:** Consider adding polls, quizzes, or comment sections to engage readers.
# *   **Links to Resources:** Provide links to relevant websites, reports, and articles for further reading.
#
# This detailed outline provides a comprehensive framework for a blog post on the rise of AI in India. Remember to tailor the content and language to your target audience and writing style. Good luck!

# %%
print(final_state['content'])
# Out:
# ## Rise of AI in India: A Nation Poised for Transformation
#
# **I. Introduction: Setting the Stage**
#
# **A. Hook:** Imagine a remote village in Rajasthan, where a pregnant woman receives an early diagnosis of gestational diabetes through an AI-powered mobile app, preventing potential complications for her and her child. This is just one glimpse into the transformative power of Artificial Intelligence (AI) unfolding across India.
#
# **B. Context:** Artificial Intelligence, the ability of machines to mimic human intelligence, is rapidly reshaping industries and societies worldwide. From self-driving cars to personalized healthcare, AI's potential is vast and constantly evolving.
#
# **C. Thesis Statement:** India is rapidly emerging as a significant player in the global AI landscape, driven by a unique combination of demographic advantages, data abundance, proactive government initiatives, a thriving startup ecosystem, and cost-effectiveness. This ascent, however, is accompanied by significant challenges that must be addressed to ensure responsible and equitable AI development.
#
# **D. Blog Structure (Brief Overview):** This blog will explore the key factors driving India's AI revolution, showcase its diverse applications across crucial sectors, highlight the challenges and concerns that need careful consideration, and finally, delve into the future prospects of AI in India, emphasizing its potential to transform the nation.
#
# **II. Key Drivers Fueling the AI Revolution in India:**
#
# **A. Demographic Advantage:**
#
# 1.  **Large and young population:** India boasts the world's largest youth population, providing a massive pool of potential AI professionals and innovators. This demographic dividend is crucial for building a skilled workforce capable of developing and deploying AI solutions.
# 2.  **Growing digital literacy:** With increasing access to affordable smartphones and internet connectivity, digital literacy is rapidly expanding across the country. This increased digital penetration creates a conducive environment for AI adoption and empowers citizens to leverage AI-powered services.
#
# **B. Data Abundance:**
#
# 1.  **Vast amounts of data generation:** India generates massive amounts of data daily through various sources, including social media, e-commerce, and government services. This vast data lake is a goldmine for training AI models, enabling them to learn and improve their accuracy and effectiveness.
# 2.  **Data localization policies:** The Indian government's emphasis on data localization aims to ensure that sensitive data remains within the country's borders. This policy encourages the development of indigenous AI solutions tailored to the specific needs and context of the Indian market.
#
# **C. Government Support and Initiatives:**
#
# 1.  **National AI Strategy:** The "National Strategy for Artificial Intelligence" outlines the government's vision for AI development in India, focusing on areas like healthcare, agriculture, education, and smart cities. The strategy aims to promote research and development, foster innovation, and create a skilled workforce in AI.
# 2.  **AI-related policies and regulations:** The government is actively developing policies and regulations to promote AI adoption while addressing ethical concerns related to data privacy, algorithmic bias, and job displacement. These policies aim to create a responsible and trustworthy AI ecosystem.
# 3.  **Funding and R&D support:** The government is investing heavily in AI research and development through various funding schemes and initiatives. These investments are crucial for fostering innovation and driving the development of cutting-edge AI technologies.
#
# **D. Thriving Startup Ecosystem:**
#
# 1.  **Emergence of AI startups:** India's startup ecosystem is witnessing a surge in AI startups developing innovative solutions for various sectors. Companies like Niramai (breast cancer screening), CropIn (agricultural intelligence), and SigTuple (medical image analysis) are examples of successful AI startups making a significant impact.
# 2.  **Venture capital investment:** Venture capitalists are increasingly investing in Indian AI startups, recognizing the immense potential of the Indian AI market. This influx of investment is fueling innovation and accelerating the growth of the AI startup ecosystem.
# 3.  **Innovation hubs and accelerators:** Numerous innovation hubs and accelerators are emerging across India, providing startups with the resources, mentorship, and networking opportunities they need to succeed in the AI space.
#
# **E. Cost-Effectiveness:**
#
# 1.  **Lower development costs compared to developed nations:** India offers a significant cost advantage in AI development compared to developed nations, making it an attractive destination for companies looking to develop and deploy AI solutions.
# 2.  **Availability of skilled but relatively affordable talent:** The availability of a large pool of skilled but relatively affordable talent in India further enhances its cost advantage in AI development. This cost-effectiveness makes India a competitive player in the global AI market.
#
# **III. AI Applications Across Key Sectors in India:**
#
# **A. Healthcare:**
#
# 1.  **AI-powered diagnostics:** AI is being used to develop diagnostic tools that can detect diseases like cancer, tuberculosis, and eye diseases at an early stage, improving treatment outcomes and saving lives.
# 2.  **Personalized medicine:** AI is enabling personalized medicine by analyzing patient data to tailor treatments to individual needs, optimizing effectiveness and minimizing side effects.
# 3.  **Remote healthcare and telemedicine:** AI is playing a crucial role in improving healthcare access in rural areas by enabling remote consultations, diagnosis, and monitoring through telemedicine platforms.
#
# **B. Agriculture:**
#
# 1.  **Precision farming:** AI-driven solutions are helping farmers optimize crop yields, reduce resource consumption, and improve efficiency through precision farming techniques.
# 2.  **Crop monitoring and disease detection:** AI is being used to monitor crop health, detect diseases, and predict yields, enabling farmers to take timely action and minimize losses.
# 3.  **Supply chain optimization:** AI is optimizing the agricultural supply chain by improving logistics, reducing waste, and ensuring timely delivery of produce to consumers.
#
# **C. Finance:**
#
# 1.  **Fraud detection and prevention:** AI algorithms are being used to identify and prevent fraudulent transactions in the banking and financial services sector, protecting consumers and businesses from financial losses.
# 2.  **Risk assessment and credit scoring:** AI is being used to evaluate creditworthiness and assess risk, enabling financial institutions to make more informed lending decisions.
# 3.  **Customer service chatbots:** AI-powered chatbots are providing 24/7 customer support, answering queries, and resolving issues efficiently.
#
# **D. Education:**
#
# 1.  **Personalized learning:** AI is adapting learning content to individual student needs, providing personalized learning experiences that improve engagement and learning outcomes.
# 2.  **Automated grading and feedback:** AI is streamlining the grading process for educators, freeing up their time to focus on teaching and mentoring students.
# 3.  **Accessible education for remote areas:** AI is facilitating online learning and bridging the education gap by providing access to quality education in remote and underserved areas.
#
# **E. Transportation:**
#
# 1.  **Smart traffic management:** AI is optimizing traffic flow, reducing congestion, and improving road safety through smart traffic management systems.
# 2.  **Autonomous vehicles:** Research and development of self-driving vehicles are underway in India, with the potential to revolutionize transportation and logistics.
# 3.  **Improved logistics and supply chain efficiency:** AI is optimizing delivery routes, improving logistics operations, and reducing transportation costs, leading to greater efficiency in the supply chain.
#
# **IV. Challenges and Concerns:**
#
# **A. Data Privacy and Security:**
#
# 1.  **Concerns about data breaches and misuse:** The increasing use of AI raises concerns about data breaches and misuse, highlighting the need for robust data protection measures.
# 2.  **Lack of clear data privacy regulations:** The absence of comprehensive data privacy laws in India poses a challenge to ensuring the responsible and ethical use of AI.
#
# **B. Ethical Considerations:**
#
# 1.  **Bias in AI algorithms:** AI algorithms can be biased if they are trained on biased data, leading to unfair or discriminatory outcomes.
# 2.  **Accountability and transparency:** Establishing clear lines of responsibility for AI decisions is crucial for ensuring accountability and transparency in AI systems.
# 3.  **Job displacement due to automation:** The automation of tasks through AI raises concerns about job displacement and the need for reskilling initiatives to prepare the workforce for the changing job market.
#
# **C. Infrastructure Gaps:**
#
# 1.  **Limited access to high-speed internet in rural areas:** The digital divide, with limited access to high-speed internet in rural areas, hinders the widespread adoption of AI technologies.
# 2.  **Lack of adequate computing infrastructure:** The lack of adequate computing infrastructure can limit the development and deployment of AI solutions.
#
# **D. Skill Gap:**
#
# 1.  **Shortage of skilled AI professionals:** A shortage of skilled AI professionals poses a challenge to the growth of the AI industry in India.
# 2.  **Need for reskilling and upskilling the workforce:** Reskilling and upskilling the workforce are essential to prepare workers for the changing job market and ensure that they can leverage AI technologies effectively.
#
# **V. The Future of AI in India: Opportunities and Potential:**
#
# **A. AI as a Growth Engine:**
#
# 1.  **Potential for economic growth and job creation:** AI has the potential to drive significant economic growth and create new job opportunities in India.
# 2.  **Improving efficiency and productivity across sectors:** AI can improve efficiency and productivity across various sectors, leading to greater economic competitiveness.
#
# **B. Global Leadership in Specific AI Domains:**
#
# 1.  **Leveraging India's strengths in specific areas (e.g., healthcare AI, agricultural AI):** India can become a global leader in specific AI domains, such as healthcare AI and agricultural AI, by leveraging its strengths and focusing on innovation.
# 2.  **Promoting collaboration between academia, industry, and government:** Fostering a collaborative ecosystem between academia, industry, and government is crucial for driving AI innovation and achieving global leadership.
#
# **C. Addressing Societal Challenges:**
#
# 1.  **Using AI to solve pressing social problems (e.g., poverty, inequality, climate change):** AI can be used to address pressing social problems such as poverty, inequality, and climate change, improving the lives of millions of people.
# 2.  **Improving the quality of life for all citizens:** AI has the potential to improve the quality of life for all citizens by providing access to better healthcare, education, and other essential services.
#
# **VI. Conclusion:**
#
# **A. Recap of Key Points:** India is experiencing a rapid rise in AI adoption, driven by demographic advantages, data abundance, government support, a thriving startup ecosystem, and cost-effectiveness. AI is being applied across key sectors like healthcare, agriculture, finance, education, and transportation, with the potential to transform the nation. However, challenges related to data privacy, ethical considerations, infrastructure gaps, and skill gaps must be addressed to ensure responsible and equitable AI development.
#
# **B. Optimistic Outlook:** The potential of AI to transform India and improve the lives of its citizens is immense. With the right policies, investments, and ethical considerations, India can harness the power of AI to achieve sustainable economic growth and address its most pressing social challenges.
#
# **C. Call to Action:** I encourage you to delve deeper into the world of AI and its applications in India. Explore the ethical implications, understand the challenges, and consider how you can contribute to shaping a future where AI benefits all of humanity.
#
# **D. Final Thought-provoking Statement:** The rise of AI in India is not just a technological revolution; it's a societal transformation. The choices we make today will determine whether AI becomes a force for good, empowering all Indians and shaping a brighter future for the world.
#
# **VII. Optional Elements:**
#
# *   **Visuals:** Include relevant images of AI applications in India, charts showing AI investment trends, and infographics illustrating the impact of AI on various sectors.
# *   **Quotes:** Incorporate quotes from industry experts, government officials, and researchers on the potential and challenges of AI in India.
# *   **Case Studies:** Feature real-world examples of successful AI implementations in India, such as the use of AI in precision farming or the development of AI-powered diagnostic tools.
# *   **Interactive Elements:** Consider adding a poll asking readers about their biggest concerns regarding AI in India, or a quiz testing their knowledge of AI applications.
# *   **Links to Resources:** Provide links to relevant websites, reports, and articles for further reading, such as the National AI Strategy document, reports from NITI Aayog, and articles from leading tech publications.
